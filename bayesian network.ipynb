# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.23-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (2.8.4)
# Collecting torch
#   Downloading torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
#      ------------------------------------ 172.4/172.4 MB 671.2 kB/s eta 0:00:00
# Collecting opt-einsum
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      -------------------------------------- 65.5/65.5 kB 321.2 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (4.64.1)
# Requirement already satisfied: pandas in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (1.4.4)
# Requirement already satisfied: scipy in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: joblib in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (1.3.1)
# Requirement already satisfied: statsmodels in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: numpy in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (1.21.5)
# Requirement already satisfied: pyparsing in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (3.0.9)
# Requirement already satisfied: scikit-learn in c:\users\thril\anaconda3\lib\site-packages (from pgmpy) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\thril\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thril\anaconda3\lib\site-packages (from pandas->pgmpy) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thril\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\thril\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\thril\anaconda3\lib\site-packages (from statsmodels->pgmpy) (21.3)
# Requirement already satisfied: typing-extensions in c:\users\thril\anaconda3\lib\site-packages (from torch->pgmpy) (4.3.0)
# Requirement already satisfied: sympy in c:\users\thril\anaconda3\lib\site-packages (from torch->pgmpy) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\thril\anaconda3\lib\site-packages (from torch->pgmpy) (2.11.3)
# Requirement already satisfied: filelock in c:\users\thril\anaconda3\lib\site-packages (from torch->pgmpy) (3.6.0)
# Requirement already satisfied: colorama in c:\users\thril\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.5)
# Requirement already satisfied: six in c:\users\thril\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thril\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\thril\anaconda3\lib\site-packages (from sympy->torch->pgmpy) (1.2.1)
# Installing collected packages: opt-einsum, torch, pgmpy
# Successfully installed opt-einsum-3.3.0 pgmpy-0.1.23 torch-2.0.1

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel
from pgmpy.inference import VariableElimination
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/thril/Downloads/heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df=df.replace('?',np.nan)

# %%
model=BayesianModel([('age','target'),('sex','target'),('cp','target'),('fbs','target'),('exang','target'),('target','restecg'),('target','chol')])
# Out:
# C:\Users\thril\anaconda3\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(

# %%
model.fit(df,estimator=MaximumLikelihoodEstimator)
inference=VariableElimination(model)

# %%
q1=inference.query(variables=['target'],evidence={'restecg':1})
print(q1)
# Out:
# +-----------+---------------+
# | target    |   phi(target) |
# +===========+===============+
# | target(0) |        0.4197 |
# +-----------+---------------+
# | target(1) |        0.5803 |
# +-----------+---------------+

# %%
q2=inference.query(variables=['target'],evidence={'cp':2})
print(q2)
# Out:
# +-----------+---------------+
# | target    |   phi(target) |
# +===========+===============+
# | target(0) |        0.4032 |
# +-----------+---------------+
# | target(1) |        0.5968 |
# +-----------+---------------+
